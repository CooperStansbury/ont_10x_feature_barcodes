# %%
import scanpy as sc
import pandas as pd

# %%
fpath = "/scratch/indikar_root/indikar1/shared_data/bm_full/bm/bm.gene_raw_feature_bc_matrix/barcodes.tsv.gz"
df = pd.read_csv(fpath, header=None)
df[0] = df[0].str.replace("-1", "")

df.to_csv("../config/barcodes.txt", index=False, header=False, sep="\t")

df.head()
# Out:
#                   0
# 0  AAACCAAAGGCGATCT
# 1  AAACCAAAGGTGAACG
# 2  AAACCATTCCCTGTCA
# 3  AAACCATTCCGCGATG
# 4  AAACCATTCCTGTCGC
